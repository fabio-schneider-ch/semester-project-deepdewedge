# %% [markdown]
# # Step 3: Tomogram Refinement

# %%
from ddw import refine_tomogram
from ddw.utils.visualization import plot_tomo_slices
from ddw.utils.mrctools import load_mrc_data
from ddw.utils.print import print_help_for_function_arguments

# %% [markdown]
# ## Refining the Tutorial Data
#
# The `ddw refine-tomogram` produces the final denoised and missing-wedge-corrected tomogram(s) using a model checkpoint produced during model fitting. You can determine which checkpoint to use by setting the `model_checkpoint_file` parameter in the `config.yaml` file. You can find checkpoint files (`.ckpt` extension) in `./tutorial_project/logs/version_0/checkpoints`. This directory contains three sub-directories:
#
# - `epoch/`: Checkpoints periodically created after a fixed number of epochs
# - `fitting_loss/`: Checkpoints created when the model achieved lowest fitting losses
# - `val_loss/`: Checkpoints created when the model achieved the lowest validation losses
#
# The frequnency and criteria for the creation of these checkpoints are arguments of `ddw fit-model`; see the output of `ddw fit-model --help` for details.
#
# Provided that there was no overfitting, the checkpoint corresponding to the highest epoch should give good results, but you can also try the ones with the lowest validation or fitting losses.
#
# The following command uses a model checkpoint contained in `./tutorial_data` which was fitted by us. If you want to use a checkpoint from your own `ddw fit-model` run, change the `model_checkpoint_file` to, e.g., `./tutorial_project/logs/version_0/checkpoints/epoch/epoch=999.ckpt`.

# %%
import os, glob

print("Current working directory:")
print(os.getcwd())

print("\nTutorial data files:")
for f in glob.glob("./tutorial_data/*"):
    print(f)

print("\nCheckpoint exists?")
print(os.path.exists("./tutorial_data/fitted_model.ckpt"))

print("\nConfig exists?")
print(os.path.exists("./config.yaml"))
# Out:
# Current working directory:
# C:\Users\fabio\Coding\Semester_Project_DeepDeWedge\notebooks\tutorial
#
# Tutorial data files:
# ./tutorial_data\fitted_model.ckpt
# ./tutorial_data\mask.mrc
# ./tutorial_data\README.txt
# ./tutorial_data\tomo_all_frames.rec
# ./tutorial_data\tomo_even_frames.rec
# ./tutorial_data\tomo_odd_frames.rec
#
# Checkpoint exists?
# True
#
# Config exists?
# True

# %%
import sys, os, subprocess

ddw_exe = os.path.join(os.path.dirname(sys.executable), "Scripts", "ddw.exe")

print("Python executable:")
print(sys.executable)

print("\nDDW executable:")
print(ddw_exe)

print("\nExists?")
print(os.path.exists(ddw_exe))
# Out:
# Python executable:
# C:\Users\fabio\anaconda3\envs\ddw_env\python.exe
#
# DDW executable:
# C:\Users\fabio\anaconda3\envs\ddw_env\Scripts\ddw.exe
#
# Exists?
# True

# %%
import subprocess

result = subprocess.run(
    [ddw_exe, "refine-tomogram", "--config", "./config.yaml"],
    capture_output=True,
    text=True
)

print("RETURN CODE:", result.returncode)

print("\n--- STDOUT ---")
print(result.stdout)

print("\n--- STDERR ---")
print(result.stderr)
# Out:
# RETURN CODE: 0
#
# --- STDOUT ---
# Saving refined tomogram to tutorial_project/refined_tomograms/tomo_even_frames+tomo_odd_frames_refined.rec
#
#
# --- STDERR ---
# C:\Users\fabio\anaconda3\envs\ddw_env\lib\site-packages\lightning_lite\utilities\cloud_io.py:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location)
#
# Computing model-input normalization statistics:   0%|          | 0/26 [00:00<?, ?it/s]C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
# C:\Users\fabio\Coding\DeepDeWedge\ddw\utils\subtomo_dataset.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file_path)
#
# Computing model-input normalization statistics:   4%|3         | 1/26 [01:25<35:39, 85.59s/it]
# Computing model-input normalization statistics:   8%|7         | 2/26 [01:26<14:13, 35.57s/it]
# Computing model-input normalization statistics:  12%|#1        | 3/26 [01:29<07:55, 20.67s/it]
# Computing model-input normalization statistics:  15%|#5        | 4/26 [01:29<04:36, 12.56s/it]
# Computing model-input normalization statistics:  19%|#9        | 5/26 [01:30<02:55,  8.37s/it]
# Computing model-input normalization statistics:  23%|##3       | 6/26 [01:30<01:51,  5.56s/it]
# Computing model-input normalization statistics:  27%|##6       | 7/26 [01:30<01:11,  3.79s/it]
# Computing model-input normalization statistics:  31%|###       | 8/26 [01:30<00:47,  2.62s/it]
# Computing model-input normalization statistics:  35%|###4      | 9/26 [01:30<00:31,  1.85s/it]
# Computing model-input normalization statistics:  38%|###8      | 10/26 [01:30<00:21,  1.31s/it]
# Computing model-input normalization statistics:  42%|####2     | 11/26 [02:39<05:31, 22.08s/it]
# Computing model-input normalization statistics:  46%|####6     | 12/26 [02:40<03:39, 15.67s/it]
# Computing model-input normalization statistics:  50%|#####     | 13/26 [02:43<02:32, 11.72s/it]
# Computing model-input normalization statistics:  54%|#####3    | 14/26 [02:43<01:38,  8.22s/it]
# Computing model-input normalization statistics:  58%|#####7    | 15/26 [02:45<01:10,  6.38s/it]
# Computing model-input normalization statistics:  62%|######1   | 16/26 [02:45<00:44,  4.50s/it]
# Computing model-input normalization statistics:  65%|######5   | 17/26 [02:46<00:28,  3.18s/it]
# Computing model-input normalization statistics:  69%|######9   | 18/26 [02:46<00:18,  2.26s/it]
# Computing model-input normalization statistics:  73%|#######3  | 19/26 [02:46<00:11,  1.62s/it]
# Computing model-input normalization statistics:  77%|#######6  | 20/26 [02:46<00:07,  1.17s/it]
# Computing model-input normalization statistics:  81%|########  | 21/26 [03:24<01:00, 12.13s/it]
# Computing model-input normalization statistics:  85%|########4 | 22/26 [03:24<00:34,  8.63s/it]
# Computing model-input normalization statistics:  88%|########8 | 23/26 [03:27<00:20,  6.95s/it]
# Computing model-input normalization statistics:  96%|#########6| 25/26 [03:27<00:03,  3.77s/it]
# Computing model-input normalization statistics: 100%|##########| 26/26 [03:27<00:00,  7.99s/it]
#
# Refining tomo0:   0%|          | 0/54 [00:00<?, ?it/s]
# Refining tomo0:   2%|1         | 1/54 [00:32<28:51, 32.66s/it]
# Refining tomo0:   4%|3         | 2/54 [01:02<26:53, 31.02s/it]
# Refining tomo0:   6%|5         | 3/54 [01:42<29:57, 35.24s/it]
# Refining tomo0:   7%|7         | 4/54 [02:16<28:55, 34.71s/it]
# Refining tomo0:   9%|9         | 5/54 [02:43<25:56, 31.77s/it]
# Refining tomo0:  11%|#1        | 6/54 [03:13<25:01, 31.27s/it]
# Refining tomo0:  13%|#2        | 7/54 [03:30<20:54, 26.68s/it]
# Refining tomo0:  15%|#4        | 8/54 [03:48<18:09, 23.69s/it]
# Refining tomo0:  17%|#6        | 9/54 [04:05<16:15, 21.68s/it]
# Refining tomo0:  19%|#8        | 10/54 [04:22<14:53, 20.32s/it]
# Refining tomo0:  20%|##        | 11/54 [04:39<13:52, 19.37s/it]
# Refining tomo0:  22%|##2       | 12/54 [04:57<13:06, 18.72s/it]
# Refining tomo0:  24%|##4       | 13/54 [05:14<12:30, 18.31s/it]
# Refining tomo0:  26%|##5       | 14/54 [05:31<12:00, 18.01s/it]
# Refining tomo0:  28%|##7       | 15/54 [05:51<12:03, 18.55s/it]
# Refining tomo0:  30%|##9       | 16/54 [06:09<11:38, 18.37s/it]
# Refining tomo0:  31%|###1      | 17/54 [06:26<11:07, 18.03s/it]
# Refining tomo0:  33%|###3      | 18/54 [06:43<10:40, 17.79s/it]
# Refining tomo0:  35%|###5      | 19/54 [07:02<10:25, 17.88s/it]
# Refining tomo0:  37%|###7      | 20/54 [07:20<10:15, 18.10s/it]
# Refining tomo0:  39%|###8      | 21/54 [07:39<10:02, 18.27s/it]
# Refining tomo0:  41%|####      | 22/54 [07:57<09:47, 18.37s/it]
# Refining tomo0:  43%|####2     | 23/54 [08:15<09:26, 18.27s/it]
# Refining tomo0:  44%|####4     | 24/54 [08:34<09:07, 18.24s/it]
# Refining tomo0:  46%|####6     | 25/54 [08:56<09:28, 19.59s/it]
# Refining tomo0:  48%|####8     | 26/54 [09:20<09:44, 20.86s/it]
# Refining tomo0:  50%|#####     | 27/54 [09:38<09:00, 20.01s/it]
# Refining tomo0:  52%|#####1    | 28/54 [09:58<08:35, 19.82s/it]
# Refining tomo0:  54%|#####3    | 29/54 [10:16<08:02, 19.31s/it]
# Refining tomo0:  56%|#####5    | 30/54 [10:34<07:37, 19.06s/it]
# Refining tomo1:  89%|########8 | 48/54 [13:59<01:42, 17.09s/it]
# Refining tomo1:  91%|######### | 49/54 [14:16<01:25, 17.09s/it]
# Refining tomo1:  93%|#########2| 50/54 [14:33<01:08, 17.08s/it]
# Refining tomo1:  94%|#########4| 51/54 [14:50<00:51, 17.07s/it]
# Refining tomo1:  96%|#########6| 52/54 [15:07<00:34, 17.08s/it]
# Refining tomo1:  98%|#########8| 53/54 [15:24<00:17, 17.10s/it]
# Refining tomo1: 100%|##########| 54/54 [15:41<00:00, 17.10s/it]
# Refining tomo1: 100%|##########| 54/54 [15:42<00:00, 17.46s/it]

# %% [markdown]
# Let's have a look at the FBP reconstruction and the tomogram refined with DeepDeWedge:

# %%
tomo_ddw = load_mrc_data("./tutorial_project/refined_tomograms/tomo_even_frames+tomo_odd_frames_refined.rec")
plot_tomo_slices(tomo_ddw.clamp(-3*tomo_ddw.std(), 3*tomo_ddw.std())).show()

tomo_fbp = load_mrc_data("./tutorial_data/tomo_all_frames.rec")
plot_tomo_slices(tomo_fbp.clamp(-3*tomo_fbp.std(), 3*tomo_fbp.std())).show()
# Out:
# C:\Users\fabio\AppData\Local\Temp\ipykernel_39276\4129945954.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot_tomo_slices(tomo_ddw.clamp(-3*tomo_ddw.std(), 3*tomo_ddw.std())).show()
# C:\Users\fabio\AppData\Local\Temp\ipykernel_39276\4129945954.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plot_tomo_slices(tomo_fbp.clamp(-3*tomo_fbp.std(), 3*tomo_fbp.std())).show()

# %% [markdown]
# ## Most Important Parameters of `refine-tomogram`
#
# You can find a full list of parameters for `ddw refine-tomogram` by executing
# ```
# conda run -n ddw_env ddw refine-tomogram --help
# ```
# in the commandline. Here, we only discuss the most important parameters. The required parameters, which cover the most relevant functionality for most users, are:

# %%
print_help_for_function_arguments(refine_tomogram, print_only_required=True)
# Out:
# ARGUMENT 'tomo0_files'
# 	REQUIRED: True
# 	HELP: List of paths to tomograms (mrc files) reconstructed from one half of the tilt series or movie frames.
# ARGUMENT 'tomo1_files'
# 	REQUIRED: True
# 	HELP: List of paths to tomograms (mrc files) reconstructed from the other half of the tilt series or movie frames.
# ARGUMENT 'model_checkpoint_file'
# 	REQUIRED: True
# 	HELP: Path to a model checkpoint file (.ckpt extension). Checkpoints saved during model fitting can be found in the 'logdir' directory specifed for the 'fit-model' command.
# ARGUMENT 'subtomo_size'
# 	REQUIRED: True
# 	HELP: Size of the cubic subtomograms to extract. This should be the same as the subtomo_size used during model fitting.
# ARGUMENT 'mw_angle'
# 	REQUIRED: True
# 	HELP: Width of the missing wedge in degrees.

# %% [markdown]
# Model checkpoints can be found in the logging directory used during `ddw fit-model`, which is typically `{project_dir}/logs`. In this concrete case, the `tutorial_project/logs` directory contains model checkpoints for various epochs, as well as those achieving the lowest validation and fitting losses. The frequency and number of checkpoints created is controlled by arguments during model fitting, see `ddw fit-model --help` for more information.
